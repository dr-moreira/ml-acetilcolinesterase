# %% [markdown]
# # Trabalho Acetilcolinesterase

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Flatten, BatchNormalization, Conv2D, MaxPool2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from sklearn.metrics import confusion_matrix
from PIL import Image
import itertools
import os
import shutil
import random
import glob
import matplotlib.pyplot as plt
import warnings

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
warnings.simplefilter(action='ignore', category=FutureWarning)
# %matplotlib inline

# %%
train_path = './data/train/'
test_path = './data/test/'

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
os.listdir(train_path)
# Out:
# ['negativo', 'positivo']

# %%
def tensor_to_image(tensor):
    tensor = np.array(tensor, dtype=np.uint8)
    if np.ndim(tensor)>3:
        assert tensor.shape[0] == 1
        tensor = tensor[0]
    return Image.fromarray(tensor)

# %% [markdown]
# ## Import Images do Disco

# %%
#train_batch = ImageDataGenerator(preprocessing_function=tf.keras.applications.vgg16.preprocess_input) \
#    .flow_from_directory(directory=train_path, target_size=(224,224), classes=['positivo', 'negativo'])
def get_ds():
    train_ds, valid_ds = tf.keras.utils.image_dataset_from_directory(
        train_path,
        labels='inferred',
        label_mode='int',
        class_names=['negativo', 'positivo'],
        color_mode='rgb',
        batch_size=15,
        image_size=(800, 800),
        shuffle=True,
        seed=33,
        validation_split=.33,
        subset='both',
    )
    return train_ds, valid_ds

# %% [markdown]
# ## Classes presentes no Dataset

# %%
train_ds, valid_ds = get_ds()
class_names = train_ds.class_names
print(class_names)
# Out:
# Found 40 files belonging to 2 classes.
# Using 27 files for training.
# Using 13 files for validation.
# ['negativo', 'positivo']

# %% [markdown]
# ### Amostra de Imagens e Classes no Dataset

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(6):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ## Criando o modelo CNN simples
# ### L1
# - Filter size 3x3x32
# - Activation Relu
# - Padding 'Same'
# - stride 2
# ### L2
# - Filter size 3x3x64
# - Activation Relu
# - Padding 'Same'
# - stride 2
# ### FC
# - Activation 'linear'
# - Classes 2 (pos, neg)

# %%
model = Sequential([
    
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding = 'same' ),
    MaxPool2D(pool_size=(2, 2), strides=2),
    Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding = 'same'),
    MaxPool2D(pool_size=(2, 2), strides=2),
    Flatten(),
    Dense(units=2, activation='linear')
])

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
history = model.fit(x=train_ds,
    validation_data= valid_ds,
    epochs=20,
    verbose=2
)
# Out:
# Epoch 1/20
# 2/2 - 7s - loss: 24139.5488 - accuracy: 0.5185 - val_loss: 17391.5859 - val_accuracy: 0.6923 - 7s/epoch - 3s/step
# Epoch 2/20
# 2/2 - 4s - loss: 22298.5391 - accuracy: 0.4074 - val_loss: 8234.2852 - val_accuracy: 0.3077 - 4s/epoch - 2s/step
# Epoch 3/20
# 2/2 - 4s - loss: 5096.0186 - accuracy: 0.5926 - val_loss: 8635.0781 - val_accuracy: 0.3077 - 4s/epoch - 2s/step
# Epoch 4/20
# 2/2 - 4s - loss: 4300.6333 - accuracy: 0.5926 - val_loss: 2650.5691 - val_accuracy: 0.3077 - 4s/epoch - 2s/step
# Epoch 5/20
# 2/2 - 4s - loss: 1143.6912 - accuracy: 0.5926 - val_loss: 201.3596 - val_accuracy: 0.3077 - 4s/epoch - 2s/step
# Epoch 6/20
# 2/2 - 4s - loss: 362.0435 - accuracy: 0.6296 - val_loss: 304.1423 - val_accuracy: 0.6923 - 4s/epoch - 2s/step
# Epoch 7/20
# 2/2 - 4s - loss: 437.1369 - accuracy: 0.4074 - val_loss: 286.7625 - val_accuracy: 0.3077 - 4s/epoch - 2s/step
# Epoch 8/20
# 2/2 - 4s - loss: 58.3613 - accuracy: 0.7037 - val_loss: 187.9845 - val_accuracy: 0.3077 - 4s/epoch - 2s/step
# Epoch 9/20
# 2/2 - 4s - loss: 5.7936 - accuracy: 0.8889 - val_loss: 50.3208 - val_accuracy: 0.3077 - 4s/epoch - 2s/step
# Epoch 10/20
# 2/2 - 4s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.8431 - val_accuracy: 0.8462 - 4s/epoch - 2s/step
# Epoch 11/20
# 2/2 - 4s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 6.0546 - val_accuracy: 0.6923 - 4s/epoch - 2s/step
# Epoch 12/20
# 2/2 - 4s - loss: 2.3842e-07 - accuracy: 1.0000 - val_loss: 9.6952 - val_accuracy: 0.7692 - 4s/epoch - 2s/step
# Epoch 13/20
# 2/2 - 4s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 10.6456 - val_accuracy: 0.7692 - 4s/epoch - 2s/step
# Epoch 14/20
# 2/2 - 4s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.8796 - val_accuracy: 0.6923 - 4s/epoch - 2s/step
# Epoch 15/20
# 2/2 - 4s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 10.7184 - val_accuracy: 0.7692 - 4s/epoch - 2s/step
# Epoch 16/20
# 2/2 - 4s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 12.1302 - val_accuracy: 0.6154 - 4s/epoch - 2s/step
# Epoch 17/20
# 2/2 - 4s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 16.4210 - val_accuracy: 0.6154 - 4s/epoch - 2s/step
# Epoch 18/20
# 2/2 - 4s - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 20.9885 - val_accuracy: 0.6154 - 4s/epoch - 2s/step
# Epoch 19/20
# 2/2 - 4s - loss: 73.9921 - accuracy: 0.8148 - val_loss: 28.1345 - val_accuracy: 0.6923 - 4s/epoch - 2s/step
# Epoch 20/20
# 2/2 - 4s - loss: 2.7254 - accuracy: 0.8889 - val_loss: 53.5198 - val_accuracy: 0.3077 - 4s/epoch - 2s/step

# %% [markdown]
# ### Gráfico da Acurácia

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## Gráfico da Loss Function

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## Predict sobre uma nova Imagem

# %%
# load image via tf.io
#img = tf.io.read_file(fname)

# convert to tensor (specify 3 channels explicitly since png files contains additional alpha channel)
# set the dtypes to align with pytorch for comparison since it will use uint8 by default
#tensor = tf.io.decode_image(img, channels=3, dtype=tf.dtypes.float32)
# (384, 470, 3)
#plt.imshow(tensor)
# resize tensor to 224 x 224
#tensor = tf.image.resize(tensor, [256, 256])
# (224, 224, 3)

# add another dimension at the front to get NHWC shape
#input_tensor = tf.expand_dims(tensor, axis=0)
# (1, 224, 224, 3)
#predict = model.predict(input_tensor)


def test_image(fname, model):
    fname = test_path + fname
    image = Image.open(fname).resize((800, 800))

    plt.imshow(image)
    image_t = tf.convert_to_tensor(image)
    input_tensor = tf.expand_dims(image_t, axis=0)

    predict = model.predict(input_tensor)


    predict_p=tf.nn.softmax(predict)
    print(f"vetor de Logits: {predict}")
    print(f"vetor de Probabilidade: {predict_p}")
    print(f"Total of Predictions: {np.sum(predict_p):0.3f}")


    print ("y = " + str(np.argmax(predict)) + ", 2L-layer model predicts a \"" + class_names[int(np.argmax(predict_p))] +  "\" picture.")

# %%
test_image("test_pos-2.jpg", model)
# Out:
# 1/1 [==============================] - 0s 167ms/step
# vetor de Logits: [[-80.66772  82.52912]]
# vetor de Probabilidade: [[0. 1.]]
# Total of Predictions: 1.000
# y = 1, 2L-layer model predicts a "positivo" picture.

# %%
test_image("test_pos-1.jpg", model)
# Out:
# 1/1 [==============================] - 0s 60ms/step
# vetor de Logits: [[-255.46841  250.2978 ]]
# vetor de Probabilidade: [[0. 1.]]
# Total of Predictions: 1.000
# y = 1, 2L-layer model predicts a "positivo" picture.

# %%
IMG_SIZE = 480

resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(IMG_SIZE, IMG_SIZE),
  layers.Rescaling(1./255)
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
])

# %%
train_ds = train_ds.shuffle(1000)

# %%
model = Sequential([
    resize_and_rescale,
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding = 'same' ),
    MaxPool2D(pool_size=(2, 2), strides=2),
    Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding = 'same' ),
    MaxPool2D(pool_size=(2, 2), strides=2),
    Flatten(),
    Dense(units=2, activation='linear')
])

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
history = model.fit(x=train_ds,
    validation_data= valid_ds,
    epochs=20,
    verbose=2
)
# Out:
# Epoch 1/20
# 2/2 - 2s - loss: 2.4229 - accuracy: 0.4815 - val_loss: 3.6139 - val_accuracy: 0.3077 - 2s/epoch - 1s/step
# Epoch 2/20
# 2/2 - 2s - loss: 1.6722 - accuracy: 0.5185 - val_loss: 1.0494 - val_accuracy: 0.6923 - 2s/epoch - 1s/step
# Epoch 3/20
# 2/2 - 2s - loss: 1.4880 - accuracy: 0.4074 - val_loss: 1.4087 - val_accuracy: 0.3077 - 2s/epoch - 1s/step
# Epoch 4/20
# 2/2 - 2s - loss: 1.2767 - accuracy: 0.5926 - val_loss: 2.6537 - val_accuracy: 0.3077 - 2s/epoch - 944ms/step
# Epoch 5/20
# 2/2 - 2s - loss: 1.1956 - accuracy: 0.5926 - val_loss: 0.6917 - val_accuracy: 0.5385 - 2s/epoch - 1s/step
# Epoch 6/20
# 2/2 - 2s - loss: 0.7791 - accuracy: 0.6667 - val_loss: 0.6783 - val_accuracy: 0.6923 - 2s/epoch - 1s/step
# Epoch 7/20
# 2/2 - 2s - loss: 0.9443 - accuracy: 0.4074 - val_loss: 0.6991 - val_accuracy: 0.3077 - 2s/epoch - 1s/step
# Epoch 8/20
# 2/2 - 2s - loss: 0.6348 - accuracy: 0.7778 - val_loss: 1.5807 - val_accuracy: 0.3077 - 2s/epoch - 953ms/step
# Epoch 9/20
# 2/2 - 2s - loss: 0.7555 - accuracy: 0.5926 - val_loss: 1.0796 - val_accuracy: 0.3077 - 2s/epoch - 929ms/step
# Epoch 10/20
# 2/2 - 2s - loss: 0.5213 - accuracy: 0.7407 - val_loss: 0.6026 - val_accuracy: 0.6923 - 2s/epoch - 954ms/step
# Epoch 11/20
# 2/2 - 2s - loss: 0.5963 - accuracy: 0.5185 - val_loss: 0.5759 - val_accuracy: 0.6923 - 2s/epoch - 957ms/step
# Epoch 12/20
# 2/2 - 2s - loss: 0.5223 - accuracy: 0.7407 - val_loss: 0.7604 - val_accuracy: 0.3077 - 2s/epoch - 884ms/step
# Epoch 13/20
# 2/2 - 2s - loss: 0.4268 - accuracy: 0.8148 - val_loss: 1.1252 - val_accuracy: 0.3077 - 2s/epoch - 985ms/step
# Epoch 14/20
# 2/2 - 2s - loss: 0.4819 - accuracy: 0.6296 - val_loss: 1.0169 - val_accuracy: 0.3077 - 2s/epoch - 883ms/step
# Epoch 15/20
# 2/2 - 2s - loss: 0.3886 - accuracy: 0.8148 - val_loss: 0.6997 - val_accuracy: 0.3846 - 2s/epoch - 917ms/step
# Epoch 16/20
# 2/2 - 2s - loss: 0.3592 - accuracy: 1.0000 - val_loss: 0.6014 - val_accuracy: 0.7692 - 2s/epoch - 915ms/step
# Epoch 17/20
# 2/2 - 2s - loss: 0.3633 - accuracy: 0.9630 - val_loss: 0.6688 - val_accuracy: 0.6154 - 2s/epoch - 959ms/step
# Epoch 18/20
# 2/2 - 2s - loss: 0.3409 - accuracy: 0.9259 - val_loss: 0.9549 - val_accuracy: 0.3077 - 2s/epoch - 940ms/step
# Epoch 19/20
# 2/2 - 2s - loss: 0.3042 - accuracy: 0.8519 - val_loss: 0.9416 - val_accuracy: 0.3077 - 2s/epoch - 923ms/step
# Epoch 20/20
# 2/2 - 2s - loss: 0.2715 - accuracy: 0.8889 - val_loss: 0.7474 - val_accuracy: 0.3077 - 2s/epoch - 995ms/step

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
test_image("test_pos-2.jpg", model)
# Out:
# 1/1 [==============================] - 0s 87ms/step
# vetor de Logits: [[-0.7440193   0.70110285]]
# vetor de Probabilidade: [[0.1907534 0.8092466]]
# Total of Predictions: 1.000
# y = 1, 2L-layer model predicts a "positivo" picture.

# %% [markdown]
# # Transfer Learning Model: EfficientNet V2 B0
# <div style='border-width: 2px;
#               border-bottom-width:4px;
#               border-bottom-color:#B6EADA;
#               border-bottom-style: solid;'></div>
# <br>
#
# EfficientNetV2 is a convolutional neural network that has faster training speed and better parameter efficiency than previous EfficientNetV1 models. To develop these models, the authors use a combination of training-aware neural architecture search and scaling, to jointly optimize training speed. The models were searched from the search space enriched with new ops such as Fused-MBConv.
#
# <center>
#     <figure>
#         <img src="https://i.postimg.cc/vBSTR3V0/59864ee4.png" alt ="MBConv and Fused-MBConv" style='width: 400px;'>
#         <figcaption>
#             Image Source: <a href="https://wandb.ai/wandb_fc/pytorch-image-models/reports/EfficientNetV2--Vmlldzo2NTkwNTQ">[Source]</a></figcaption>
#     </figure>
# </center>
#
# **For more information follow the links below:**
# > - EfficientNet V2 Paper (2021): [EfficientNetV2: Smaller Models and Faster Training](https://arxiv.org/pdf/2104.00298v2.pdf)
# > - [EfficientNet: Improving Accuracy and Efficiency through AutoML and Model Scaling](https://ai.googleblog.com/2019/05/efficientnet-improving-accuracy-and.html)
# > - [Wandb: EfficientNetV2](https://wandb.ai/wandb_fc/pytorch-image-models/reports/EfficientNetV2--Vmlldzo2NTkwNTQ)
#
# <a id="tfhub"></a>
# ## TensorFlow Hub
#
# TensorFlow Hub is a repository of trained machine learning models ready for fine-tuning and deployable anywhere. Reuse trained models like BERT and Faster R-CNN with just a few lines of code.
#
# In this section we'll be using pre-trained models from TensorFlow Hub.
#
# > For more information on TensorFlow Hub or if you would like to access the same models in PyTorch/JAX, check out the following links:
# > - [TensorFlow Hub](https://www.tensorflow.org/hub)
# > - [HuggingFace🤗](https://huggingface.co/)

# %%
import tensorflow_hub as hub

# %%
# Here's a function to get any model/preprocessor from tensorflow hub
def get_tfhub_model(model_link, model_name, model_trainable=False):
    return hub.KerasLayer(model_link,
                          trainable=model_trainable,
                          name=model_name)

# %%
# Get EfficientNet V2 B0 here
efficientnet_v2_url = 'https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_b0/feature_vector/2'
model_name = 'efficientnet_v2_b0'

# Set trainable to False for inference-only 
set_trainable=False

efficientnet_v2_b0 = get_tfhub_model(efficientnet_v2_url, 
                                     model_name, 
                                     model_trainable=set_trainable)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(224, 224),
  layers.Rescaling(1./255)
])

# %%
def efficientnet_v2_model():
    
    initializer = tf.keras.initializers.GlorotNormal(seed=123)
    
    efficientnet_v2_sequential = Sequential([
        resize_and_rescale,
        efficientnet_v2_b0,
        layers.Dropout(0.2),
        layers.Dense(512, activation='relu', kernel_initializer=initializer),
        layers.Dense(256, activation='relu', kernel_initializer=initializer),
        layers.Dense(128, activation='relu', kernel_initializer=initializer),
        layers.Dense(64, activation='relu', kernel_initializer=initializer),
        layers.Dense(32, activation='relu', kernel_initializer=initializer),
        layers.Dense(2, dtype=tf.float32, activation='linear', kernel_initializer=initializer)
    ], name='efficientnet_v2_sequential_model')
    
    return efficientnet_v2_sequential

# %%
# Generate Model
model_efficientnet_v2 = efficientnet_v2_model()

model_efficientnet_v2.build([None, 224, 224, 3]) 

# Generate Summary of the Model
model_efficientnet_v2.summary()
# Out:
# WARNING:tensorflow:From /home/daniel/anaconda3/envs/deep_learning/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /home/daniel/anaconda3/envs/deep_learning/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# Model: "efficientnet_v2_sequential_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 224, 224, 3)       0
#
#  efficientnet_v2_b0 (KerasLa  (None, 1280)             5919312
#  yer)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense_2 (Dense)             (None, 512)               655872
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 6,749,810
# Trainable params: 830,498
# Non-trainable params: 5,919,312
# _________________________________________________________________

# %%
model_efficientnet_v2.compile(optimizer=Adam(learning_rate=0.0001), loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
train_ds, valid_ds = get_ds()
# Out:
# Found 40 files belonging to 2 classes.
# Using 27 files for training.
# Using 13 files for validation.

# %%
history = model_efficientnet_v2.fit(x=train_ds,
    validation_data= valid_ds,
    epochs=50,
    verbose=2
)
# Out:
# Epoch 1/50
# 2/2 - 11s - loss: 0.8917 - accuracy: 0.5926 - val_loss: 0.8851 - val_accuracy: 0.3077 - 11s/epoch - 5s/step
# Epoch 2/50
# 2/2 - 3s - loss: 0.7140 - accuracy: 0.5556 - val_loss: 0.8138 - val_accuracy: 0.3846 - 3s/epoch - 1s/step
# Epoch 3/50
# 2/2 - 3s - loss: 0.6300 - accuracy: 0.6667 - val_loss: 0.7798 - val_accuracy: 0.4615 - 3s/epoch - 1s/step
# Epoch 4/50
# 2/2 - 3s - loss: 0.5911 - accuracy: 0.6667 - val_loss: 0.7349 - val_accuracy: 0.4615 - 3s/epoch - 2s/step
# Epoch 5/50
# 2/2 - 3s - loss: 0.6008 - accuracy: 0.7037 - val_loss: 0.6944 - val_accuracy: 0.6154 - 3s/epoch - 2s/step
# Epoch 6/50
# 2/2 - 3s - loss: 0.5733 - accuracy: 0.7778 - val_loss: 0.6844 - val_accuracy: 0.5385 - 3s/epoch - 1s/step
# Epoch 7/50
# 2/2 - 3s - loss: 0.5322 - accuracy: 0.8889 - val_loss: 0.6984 - val_accuracy: 0.5385 - 3s/epoch - 2s/step
# Epoch 8/50
# 2/2 - 3s - loss: 0.4958 - accuracy: 0.8148 - val_loss: 0.7155 - val_accuracy: 0.4615 - 3s/epoch - 1s/step
# Epoch 9/50
# 2/2 - 4s - loss: 0.4670 - accuracy: 0.8519 - val_loss: 0.7018 - val_accuracy: 0.5385 - 4s/epoch - 2s/step
# Epoch 10/50
# 2/2 - 3s - loss: 0.4464 - accuracy: 0.7407 - val_loss: 0.6899 - val_accuracy: 0.6154 - 3s/epoch - 2s/step
# Epoch 11/50
# 2/2 - 3s - loss: 0.4533 - accuracy: 0.8519 - val_loss: 0.6615 - val_accuracy: 0.6154 - 3s/epoch - 1s/step
# Epoch 12/50
# 2/2 - 3s - loss: 0.3698 - accuracy: 0.9259 - val_loss: 0.6308 - val_accuracy: 0.7692 - 3s/epoch - 2s/step
# Epoch 13/50
# 2/2 - 3s - loss: 0.3379 - accuracy: 0.9630 - val_loss: 0.6113 - val_accuracy: 0.7692 - 3s/epoch - 2s/step
# Epoch 14/50
# 2/2 - 3s - loss: 0.3426 - accuracy: 0.9259 - val_loss: 0.5808 - val_accuracy: 0.7692 - 3s/epoch - 2s/step
# Epoch 15/50
# 2/2 - 3s - loss: 0.2910 - accuracy: 0.9259 - val_loss: 0.5484 - val_accuracy: 0.6923 - 3s/epoch - 1s/step
# Epoch 16/50
# 2/2 - 3s - loss: 0.3006 - accuracy: 0.8889 - val_loss: 0.5220 - val_accuracy: 0.7692 - 3s/epoch - 1s/step
# Epoch 17/50
# 2/2 - 3s - loss: 0.2620 - accuracy: 0.9259 - val_loss: 0.4834 - val_accuracy: 0.7692 - 3s/epoch - 2s/step
# Epoch 18/50
# 2/2 - 3s - loss: 0.2069 - accuracy: 1.0000 - val_loss: 0.4592 - val_accuracy: 0.7692 - 3s/epoch - 1s/step
# Epoch 19/50
# 2/2 - 3s - loss: 0.1774 - accuracy: 1.0000 - val_loss: 0.4402 - val_accuracy: 0.8462 - 3s/epoch - 2s/step
# Epoch 20/50
# 2/2 - 3s - loss: 0.2249 - accuracy: 0.9630 - val_loss: 0.4436 - val_accuracy: 0.7692 - 3s/epoch - 1s/step
# Epoch 21/50
# 2/2 - 3s - loss: 0.1821 - accuracy: 0.9630 - val_loss: 0.4458 - val_accuracy: 0.7692 - 3s/epoch - 2s/step
# Epoch 22/50
# 2/2 - 3s - loss: 0.1207 - accuracy: 1.0000 - val_loss: 0.4469 - val_accuracy: 0.7692 - 3s/epoch - 2s/step
# Epoch 23/50
# 2/2 - 4s - loss: 0.1254 - accuracy: 1.0000 - val_loss: 0.4199 - val_accuracy: 0.7692 - 4s/epoch - 2s/step
# Epoch 24/50
# 2/2 - 3s - loss: 0.1193 - accuracy: 1.0000 - val_loss: 0.3834 - val_accuracy: 0.8462 - 3s/epoch - 2s/step
# Epoch 25/50
# 2/2 - 4s - loss: 0.1138 - accuracy: 1.0000 - val_loss: 0.3426 - val_accuracy: 0.8462 - 4s/epoch - 2s/step
# Epoch 26/50
# 2/2 - 4s - loss: 0.1015 - accuracy: 1.0000 - val_loss: 0.3197 - val_accuracy: 0.8462 - 4s/epoch - 2s/step
# Epoch 27/50
# 2/2 - 5s - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.3102 - val_accuracy: 0.8462 - 5s/epoch - 3s/step
# Epoch 28/50
# 2/2 - 3s - loss: 0.0784 - accuracy: 1.0000 - val_loss: 0.3205 - val_accuracy: 0.8462 - 3s/epoch - 1s/step
# Epoch 29/50
# 2/2 - 3s - loss: 0.1211 - accuracy: 0.9630 - val_loss: 0.3304 - val_accuracy: 0.8462 - 3s/epoch - 2s/step
# Epoch 30/50
# 2/2 - 3s - loss: 0.0733 - accuracy: 0.9630 - val_loss: 0.2997 - val_accuracy: 0.9231 - 3s/epoch - 2s/step
# Epoch 31/50
# 2/2 - 3s - loss: 0.0595 - accuracy: 1.0000 - val_loss: 0.2640 - val_accuracy: 0.9231 - 3s/epoch - 1s/step
# Epoch 32/50
# 2/2 - 4s - loss: 0.0425 - accuracy: 1.0000 - val_loss: 0.2454 - val_accuracy: 0.9231 - 4s/epoch - 2s/step
# Epoch 33/50
# 2/2 - 3s - loss: 0.0447 - accuracy: 1.0000 - val_loss: 0.2332 - val_accuracy: 0.9231 - 3s/epoch - 1s/step
# Epoch 34/50
# 2/2 - 3s - loss: 0.0464 - accuracy: 1.0000 - val_loss: 0.2238 - val_accuracy: 0.9231 - 3s/epoch - 1s/step
# Epoch 35/50
# 2/2 - 3s - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.2200 - val_accuracy: 0.9231 - 3s/epoch - 2s/step
# Epoch 36/50
# 2/2 - 3s - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.2160 - val_accuracy: 0.9231 - 3s/epoch - 2s/step
# Epoch 37/50
# 2/2 - 3s - loss: 0.0349 - accuracy: 1.0000 - val_loss: 0.2156 - val_accuracy: 0.9231 - 3s/epoch - 2s/step
# Epoch 38/50
# 2/2 - 4s - loss: 0.0287 - accuracy: 1.0000 - val_loss: 0.2340 - val_accuracy: 0.9231 - 4s/epoch - 2s/step
# Epoch 39/50
# 2/2 - 3s - loss: 0.0531 - accuracy: 0.9630 - val_loss: 0.2352 - val_accuracy: 0.9231 - 3s/epoch - 2s/step
# Epoch 40/50
# 2/2 - 3s - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.2458 - val_accuracy: 0.8462 - 3s/epoch - 1s/step
# Epoch 41/50
# 2/2 - 3s - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.2556 - val_accuracy: 0.8462 - 3s/epoch - 1s/step
# Epoch 42/50
# 2/2 - 3s - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.2599 - val_accuracy: 0.8462 - 3s/epoch - 1s/step
# Epoch 43/50
# 2/2 - 3s - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.2486 - val_accuracy: 0.8462 - 3s/epoch - 1s/step
# Epoch 44/50
# 2/2 - 3s - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.2166 - val_accuracy: 0.9231 - 3s/epoch - 1s/step
# Epoch 45/50
# 2/2 - 3s - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.1959 - val_accuracy: 1.0000 - 3s/epoch - 2s/step
# Epoch 46/50
# 2/2 - 3s - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 1.0000 - 3s/epoch - 2s/step
# Epoch 47/50
# 2/2 - 3s - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.1748 - val_accuracy: 1.0000 - 3s/epoch - 1s/step
# Epoch 48/50
# 2/2 - 3s - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.1699 - val_accuracy: 1.0000 - 3s/epoch - 1s/step
# Epoch 49/50
# 2/2 - 3s - loss: 0.0359 - accuracy: 1.0000 - val_loss: 0.1664 - val_accuracy: 1.0000 - 3s/epoch - 1s/step
# Epoch 50/50
# 2/2 - 3s - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.1594 - val_accuracy: 1.0000 - 3s/epoch - 1s/step

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
test_image("test_pos-2.jpg", model_efficientnet_v2)
# Out:
# 1/1 [==============================] - 1s 922ms/step
# vetor de Logits: [[-2.0341387  -0.13129592]]
# vetor de Probabilidade: [[0.12978707 0.8702129 ]]
# Total of Predictions: 1.000
# y = 1, 2L-layer model predicts a "positivo" picture.

# %%
test_image("test_pos-1.jpg", model)
# Out:
# 1/1 [==============================] - 0s 49ms/step
# vetor de Logits: [[-1.2447786  1.208968 ]]
# vetor de Probabilidade: [[0.07916498 0.920835  ]]
# Total of Predictions: 1.000
# y = 1, 2L-layer model predicts a "positivo" picture.
